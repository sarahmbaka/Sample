# %%
# Pandas and numpy for data manipulation
import pandas as pd
import numpy as np

# quick EDA analyses
#import pandas_profiling as pd_profile

# Set today's date
import datetime as dt
from datetime import datetime, timedelta
import calendar
today = dt.datetime.today().strftime("%Y-%m-%d")

#date of data extraction
date_of_classification = dt.datetime(2020,2,21,9,0,0)  # replace date with year,month,day,hour,minute,sec

# Set current time
import time 
start_time = time.time()


# No warnings about setting value on copy of slice
pd.options.mode.chained_assignment = None
pd.set_option("display.max_columns", 150)
pd.set_option("display.max_rows", 10000)
pd.set_option("display.float_format", lambda x: '%.2f' % x)


# Supress unnecessary warnings so that presentation looks clean
import warnings
warnings.filterwarnings('ignore')

#in-house tools for columns renaming, dates transformation and checking missing values
from sfl_tools import *
# computing Weight of Evidence (WOE) and Information value(WOE)
from WOE import *

# for splitting flatfile into training and test set
from sklearn.model_selection import train_test_split

# %%
#data dictionaries
data_directory = "../data/"
data_output_directory = data_directory + "notebook_outputs/" 
data_flatfile_directory = data_directory + "flatfile/"
metropol_data_output_directory =  data_output_directory + "metropol_summary_features/"

# %%
interna_data = pd.read_csv(data_flatfile_directory + "flatfile_survey_only.csv")
internal_data_pre_acceptance = pd.read_csv(data_output_directory + "survey_features_flatfile_pre_acceptance.csv")

# %%
interna_data.columns
# Out:
# Index(['Unnamed: 0', 'farmer_age.group', 'farm_size_stayed_same',
#        'yield_kg.group', 'other_non-farm_income.binary', 'education_level',
#        'schooling_years.group', 'dependants.group', 'other_crops.binary',
#        'cooperative_member', 'agric_loans_type.inputs',
#        'agric_loans_type.mechanisation', 'loans_type.inputs_mech',
#        'protection_product.zetanil', 'protection_product.redomil',
#        'status_by_margins_60', 'status_by_margins_30', 'order_id',
#        'order_value', 'order_value.group', 'total_arrears', 'margin',
#        'age_of_loan'],
#       dtype='object')

# %%
#interna_data.dtypes

# %%
#internal_data_pre_acceptance.columns

# %%
non_modelling_features = ['Unnamed: 0','status_by_margins_60','order_id','total_arrears','margin','age_of_loan']
internal_data = interna_data.drop(non_modelling_features, axis = 1)

# %%
non_modelling_features = ['Unnamed: 0','status_by_margins_60','total_arrears','margin','age_of_loan',
                          'total_arrears', 'margin','county.category', 'ward.category', 'agent_name.category',
                          'loan_cohort.category','agent_name', 'county', 'ward', 'loan_cohort']
pre_acceptance_df = internal_data_pre_acceptance.drop(non_modelling_features, axis = 1)

# %%
X = internal_data.drop(['status_by_margins_30'], axis=1)
y = internal_data['status_by_margins_30']

# %%
#import pandas as pd
#import numpy as np
import pandas.core.algorithms as algos
from pandas import Series
import scipy.stats.stats as stats
import re
import traceback
import string

max_bin = 20
force_bin = 3

# %%
# define a binning function
def mono_bin(Y, X, n = max_bin):
    
    df1 = pd.DataFrame({"X": X, "Y": Y})
    justmiss = df1[['X','Y']][df1.X.isnull()]
    notmiss = df1[['X','Y']][df1.X.notnull()]
    r = 0
    while np.abs(r) < 1:
        try:
            d1 = pd.DataFrame({"X": notmiss.X, "Y": notmiss.Y, "Bucket": pd.qcut(notmiss.X, n)})
            d2 = d1.groupby('Bucket', as_index=True)
            r, p = stats.spearmanr(d2.mean().X, d2.mean().Y)
            n = n - 1 
        except Exception as e:
            n = n - 1

    if len(d2) == 1:
        n = force_bin         
        bins = algos.quantile(notmiss.X, np.linspace(0, 1, n))
        if len(np.unique(bins)) == 2:
            bins = np.insert(bins, 0, 1)
            bins[1] = bins[1]-(bins[1]/2)
        d1 = pd.DataFrame({"X": notmiss.X, "Y": notmiss.Y, "Bucket": pd.cut(notmiss.X, np.unique(bins),include_lowest=True)}) 
        d2 = d1.groupby('Bucket', as_index=True)
    
    d3 = pd.DataFrame({},index=[])
    d3["MIN_VALUE"] = d2.min().X
    d3["MAX_VALUE"] = d2.max().X
    d3["COUNT"] = d2.count().Y
    d3["EVENT"] = d2.sum().Y
    d3["NONEVENT"] = d2.count().Y - d2.sum().Y
    d3=d3.reset_index(drop=True)
    
    if len(justmiss.index) > 0:
        d4 = pd.DataFrame({'MIN_VALUE':np.nan},index=[0])
        d4["MAX_VALUE"] = np.nan
        d4["COUNT"] = justmiss.count().Y
        d4["EVENT"] = justmiss.sum().Y
        d4["NONEVENT"] = justmiss.count().Y - justmiss.sum().Y
        d3 = d3.append(d4,ignore_index=True)
    
    d3["EVENT_RATE"] = d3.EVENT/d3.COUNT
    d3["NON_EVENT_RATE"] = d3.NONEVENT/d3.COUNT
    d3["DIST_EVENT"] = d3.EVENT/d3.sum().EVENT
    d3["DIST_NON_EVENT"] = d3.NONEVENT/d3.sum().NONEVENT
    d3["WOE"] = np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["IV"] = (d3.DIST_EVENT-d3.DIST_NON_EVENT)*np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["VAR_NAME"] = "VAR"
    d3 = d3[['VAR_NAME','MIN_VALUE', 'MAX_VALUE', 'COUNT', 'EVENT', 'EVENT_RATE', 'NONEVENT', 'NON_EVENT_RATE', 'DIST_EVENT','DIST_NON_EVENT','WOE', 'IV']]       
    d3 = d3.replace([np.inf, -np.inf], 0)
    d3.IV = d3.IV.sum()
    
    return(d3)

# %%
def char_bin(Y, X):
        
    df1 = pd.DataFrame({"X": X, "Y": Y})
    justmiss = df1[['X','Y']][df1.X.isnull()]
    notmiss = df1[['X','Y']][df1.X.notnull()]    
    df2 = notmiss.groupby('X',as_index=True)
    
    d3 = pd.DataFrame({},index=[])
    d3["COUNT"] = df2.count().Y
    d3["MIN_VALUE"] = df2.sum().Y.index
    d3["MAX_VALUE"] = d3["MIN_VALUE"]
    d3["EVENT"] = df2.sum().Y
    d3["NONEVENT"] = df2.count().Y - df2.sum().Y
    
    if len(justmiss.index) > 0:
        d4 = pd.DataFrame({'MIN_VALUE':np.nan},index=[0])
        d4["MAX_VALUE"] = np.nan
        d4["COUNT"] = justmiss.count().Y
        d4["EVENT"] = justmiss.sum().Y
        d4["NONEVENT"] = justmiss.count().Y - justmiss.sum().Y
        d3 = d3.append(d4,ignore_index=True)
    
    d3["EVENT_RATE"] = d3.EVENT/d3.COUNT
    d3["NON_EVENT_RATE"] = d3.NONEVENT/d3.COUNT
    d3["DIST_EVENT"] = d3.EVENT/d3.sum().EVENT
    d3["DIST_NON_EVENT"] = d3.NONEVENT/d3.sum().NONEVENT
    d3["WOE"] = np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["IV"] = (d3.DIST_EVENT-d3.DIST_NON_EVENT)*np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["VAR_NAME"] = "VAR"
    d3 = d3[['VAR_NAME','MIN_VALUE', 'MAX_VALUE', 'COUNT', 'EVENT', 'EVENT_RATE', 'NONEVENT', 'NON_EVENT_RATE', 'DIST_EVENT','DIST_NON_EVENT','WOE', 'IV']]      
    d3 = d3.replace([np.inf, -np.inf], 0)
    d3.IV = d3.IV.sum()
    d3 = d3.reset_index(drop=True)
    
    return(d3)

# %%
def data_vars(df1, target):
    
    stack = traceback.extract_stack()
    filename, lineno, function_name, code = stack[-2]
    vars_name = re.compile(r'\((.*?)\).*$').search(code).groups()[0]
    final = (re.findall(r"[\w']+", vars_name))[-1]
    
    x = df1.dtypes.index
    count = -1
    
    for i in x:
        if i.upper() not in (final.upper()):
            if np.issubdtype(df1[i], np.number) and len(Series.unique(df1[i])) > 2:
                conv = mono_bin(target, df1[i])
                conv["VAR_NAME"] = i
                count = count + 1
            else:
                conv = char_bin(target, df1[i])
                conv["VAR_NAME"] = i            
                count = count + 1
                
            if count == 0:
                iv_df = conv
            else:
                iv_df = iv_df.append(conv,ignore_index=True)
    
    iv = pd.DataFrame({'IV':iv_df.groupby('VAR_NAME').IV.max()})
    iv = iv.reset_index()
    return(iv_df,iv)

# %%
final_iv, IV = data_vars(X,y)

# %%
final_iv
# Out:
#                           VAR_NAME         MIN_VALUE         MAX_VALUE  COUNT  \
# 0                 farmer_age.group             25-29             25-29    255
# 1                 farmer_age.group             30-39             30-39    679
# 2                 farmer_age.group             40-49             40-49    546
# 3                 farmer_age.group             50-59             50-59    294
# 4                 farmer_age.group               60+               60+    146
# 5                 farmer_age.group              _<25              _<25     89
# 6            farm_size_stayed_same                No                No   1211
# 7            farm_size_stayed_same               Yes               Yes    798
# 8                   yield_kg.group             blank             blank     68
# 9                   yield_kg.group       01000-03000       01000-03000    506
# 10                  yield_kg.group       03000-06000       03000-06000    517
# 11                  yield_kg.group       06000-10000       06000-10000    331
# 12                  yield_kg.group            10000+            10000+    349
# 13                  yield_kg.group           _<01000           _<01000    238
# 14    other_non-farm_income.binary                No                No    479
# 15    other_non-farm_income.binary               Yes               Yes   1530
# 16                 education_level             blank             blank     58
# 17                 education_level           College           College    247
# 18                 education_level      No schooling      No schooling     72
# 19                 education_level    Primary School    Primary School    766
# 20                 education_level  Secondary School  Secondary School    785
# 21                 education_level        University        University     81
# 22           schooling_years.group               12+               12+    472
# 23           schooling_years.group          8.0-12.0          8.0-12.0    718
# 24           schooling_years.group             _<8.0             _<8.0    819
# 25                dependants.group           2.0-4.0           2.0-4.0    750
# 26                dependants.group           4.0-6.0           4.0-6.0    558
# 27                dependants.group                6+                6+    299
# 28                dependants.group             _<2.0             _<2.0    402
# 29              other_crops.binary                No                No    265
# 30              other_crops.binary               Yes               Yes   1744
# 31              cooperative_member             blank             blank    101
# 32              cooperative_member                No                No    884
# 33              cooperative_member               Yes               Yes   1024
# 34         agric_loans_type.inputs                No                No    797
# 35         agric_loans_type.inputs               Yes               Yes   1212
# 36  agric_loans_type.mechanisation                No                No   1780
# 37  agric_loans_type.mechanisation               Yes               Yes    229
# 38          loans_type.inputs_mech                No                No   1817
# 39          loans_type.inputs_mech               Yes               Yes    192
# 40      protection_product.zetanil                No                No   1824
# 41      protection_product.zetanil               Yes               Yes    185
# 42      protection_product.redomil                No                No   1578
# 43      protection_product.redomil               Yes               Yes    431
# 44                     order_value              2950             13000   1033
# 45                     order_value             13010             70090    976
# 46               order_value.group       12500-19500       12500-19500    503
# 47               order_value.group            19500+            19500+    561
# 48               order_value.group        7500-12500        7500-12500    467
# 49               order_value.group            _<7500            _<7500    478
#
#     EVENT  EVENT_RATE  NONEVENT  NON_EVENT_RATE  DIST_EVENT  DIST_NON_EVENT  \
# 0      90        0.35       165            0.65        0.12            0.13
# 1     247        0.36       432            0.64        0.34            0.34
# 2     207        0.38       339            0.62        0.28            0.27
# 3     104        0.35       190            0.65        0.14            0.15
# 4      53        0.36        93            0.64        0.07            0.07
# 5      33        0.37        56            0.63        0.04            0.04
# 6     431        0.36       780            0.64        0.59            0.61
# 7     303        0.38       495            0.62        0.41            0.39
# 8      14        0.21        54            0.79        0.02            0.04
# 9     188        0.37       318            0.63        0.26            0.25
# 10    198        0.38       319            0.62        0.27            0.25
# 11    116        0.35       215            0.65        0.16            0.17
# 12    136        0.39       213            0.61        0.19            0.17
# 13     82        0.34       156            0.66        0.11            0.12
# 14    162        0.34       317            0.66        0.22            0.25
# 15    572        0.37       958            0.63        0.78            0.75
# 16     20        0.34        38            0.66        0.03            0.03
# 17     82        0.33       165            0.67        0.11            0.13
# 18     21        0.29        51            0.71        0.03            0.04
# 19    299        0.39       467            0.61        0.41            0.37
# 20    288        0.37       497            0.63        0.39            0.39
# 21     24        0.30        57            0.70        0.03            0.04
# 22    164        0.35       308            0.65        0.22            0.24
# 23    258        0.36       460            0.64        0.35            0.36
# 24    312        0.38       507            0.62        0.43            0.40
# 25    300        0.40       450            0.60        0.41            0.35
# 26    182        0.33       376            0.67        0.25            0.29
# 27    108        0.36       191            0.64        0.15            0.15
# 28    144        0.36       258            0.64        0.20            0.20
# 29    101        0.38       164            0.62        0.14            0.13
# 30    633        0.36      1111            0.64        0.86            0.87
# 31     16        0.16        85            0.84        0.02            0.07
# 32    347        0.39       537            0.61        0.47            0.42
# 33    371        0.36       653            0.64        0.51            0.51
# 34    283        0.36       514            0.64        0.39            0.40
# 35    451        0.37       761            0.63        0.61            0.60
# 36    645        0.36      1135            0.64        0.88            0.89
# 37     89        0.39       140            0.61        0.12            0.11
# 38    665        0.37      1152            0.63        0.91            0.90
# 39     69        0.36       123            0.64        0.09            0.10
# 40    665        0.36      1159            0.64        0.91            0.91
# 41     69        0.37       116            0.63        0.09            0.09
# 42    581        0.37       997            0.63        0.79            0.78
# 43    153        0.35       278            0.65        0.21            0.22
# 44    353        0.34       680            0.66        0.48            0.53
# 45    381        0.39       595            0.61        0.52            0.47
# 46    202        0.40       301            0.60        0.28            0.24
# 47    213        0.38       348            0.62        0.29            0.27
# 48    154        0.33       313            0.67        0.21            0.25
# 49    165        0.35       313            0.65        0.22            0.25
#
#      WOE   IV
# 0  -0.05 0.00
# 1  -0.01 0.00
# 2   0.06 0.00
# 3  -0.05 0.00
# 4  -0.01 0.00
# 5   0.02 0.00
# 6  -0.04 0.00
# 7   0.06 0.00
# 8  -0.80 0.02
# 9   0.03 0.02
# 10  0.08 0.02
# 11 -0.06 0.02
# 12  0.10 0.02
# 13 -0.09 0.02
# 14 -0.12 0.00
# 15  0.04 0.00
# 16 -0.09 0.01
# 17 -0.15 0.01
# 18 -0.34 0.01
# 19  0.11 0.01
# 20  0.01 0.01
# 21 -0.31 0.01
# 22 -0.08 0.00
# 23 -0.03 0.00
# 24  0.07 0.00
# 25  0.15 0.02
# 26 -0.17 0.02
# 27 -0.02 0.02
# 28 -0.03 0.02
# 29  0.07 0.00
# 30 -0.01 0.00
# 31 -1.12 0.06
# 32  0.12 0.06
# 33 -0.01 0.06
# 34 -0.04 0.00
# 35  0.03 0.00
# 36 -0.01 0.00
# 37  0.10 0.00
# 38  0.00 0.00
# 39 -0.03 0.00
# 40 -0.00 0.00
# 41  0.03 0.00
# 42  0.01 0.00
# 43 -0.04 0.00
# 44 -0.10 0.01
# 45  0.11 0.01
# 46  0.15 0.01
# 47  0.06 0.01
# 48 -0.16 0.01
# 49 -0.09 0.01

# %%
final_iv.to_csv(data_output_directory + "internal_woe_iv_values.csv")

# %%
#Exporting the feature list to local folder
df_feature_list_sorted = IV.sort_values('IV', ascending=False)
df_feature_list_sorted.to_csv(data_output_directory + "internal_data_IV_feature_list.csv")

# %%
df_feature_list_sorted.head(20)
# Out:
#                           VAR_NAME   IV
# 2               cooperative_member 0.06
# 15                  yield_kg.group 0.02
# 3                 dependants.group 0.02
# 4                  education_level 0.01
# 9                order_value.group 0.01
# 8                      order_value 0.01
# 11    other_non-farm_income.binary 0.00
# 14           schooling_years.group 0.00
# 5            farm_size_stayed_same 0.00
# 6                 farmer_age.group 0.00
# 0          agric_loans_type.inputs 0.00
# 1   agric_loans_type.mechanisation 0.00
# 10              other_crops.binary 0.00
# 12      protection_product.redomil 0.00
# 13      protection_product.zetanil 0.00
# 7           loans_type.inputs_mech 0.00

# %%
# X = pre_acceptance_df.drop(['status_by_margins_30'], axis=1)
# y = pre_acceptance_df['status_by_margins_30']

# %%
# final_iv, IV = data_vars(X,y)

# %%
# final_iv.to_csv(data_output_directory + "pre_acceptance_woe_iv_values.csv")

# %%
#Exporting the feature list to local folder
# df_feature_list_sorted = IV.sort_values('IV', ascending=False)
# df_feature_list_sorted.to_csv(data_output_directory + "pre_acceptance_IV_feature_list.csv")
